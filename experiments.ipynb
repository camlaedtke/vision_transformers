# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from vit_keras import vit, utils

# %%
image_size = 768
classes = utils.get_imagenet_classes()

# %%
model = vit.vit_l16(
    image_size=image_size,
    pretrained=True,
    include_top=False,
    pretrained_top=False,
    weights="imagenet21k"
)
# Out:
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-L_16_imagenet21k.npz
# 1307090944/1307089850 [==============================] - 89s 0us/step
# /opt/anaconda3/envs/ml_env/lib/python3.7/site-packages/vit_keras/utils.py:79: UserWarning: Resizing position embeddings from 14 to 48
#   UserWarning,

# %%
plot_model(model, dpi=64, show_shapes=True, expand_nested=True)

# %%
model.summary()
# Out:
# Model: "vit-l16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 768, 768, 3)]     0
# _________________________________________________________________
# embedding (Conv2D)           (None, 48, 48, 1024)      787456
# _________________________________________________________________
# reshape (Reshape)            (None, 2304, 1024)        0
# _________________________________________________________________
# class_token (ClassToken)     (None, 2305, 1024)        1024
# _________________________________________________________________
# Transformer/posembed_input ( (None, 2305, 1024)        2360320
# _________________________________________________________________
# Transformer/encoderblock_0 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_1 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_2 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_3 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_4 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_5 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_6 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_7 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_8 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_9 ( ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_10  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_11  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_12  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_13  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_14  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_15  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_16  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_17  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_18  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_19  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_20  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_21  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_22  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoderblock_23  ((None, 2305, 1024), (Non 12596224
# _________________________________________________________________
# Transformer/encoder_norm (La (None, 2305, 1024)        2048
# _________________________________________________________________
# ExtractToken (Lambda)        (None, 1024)              0
# _________________________________________________________________
# pre_logits (Dense)           (None, 1024)              1049600
# =================================================================
# Total params: 306,509,824
# Trainable params: 306,509,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save_weights("weights/vit_l16_imagenet21k.h5")
